# %%
# !python3 "/content/drive/My Drive/srcnn_pytorch/datasets.py"

# %%
# !python3 "/content/drive/My Drive/srcnn_pytorch/utils.py"

# %%
# !python3 "/content/drive/My Drive/srcnn_pytorch/model.py"

# %%
# !python3 "/content/drive/My Drive/srcnn_pytorch/train.py" \
--train_file "/content/drive/My Drive/srcnn_pytorch/dataset/for_training/91-image_x3.h5" \
--eval_file "/content/drive/My Drive/srcnn_pytorch/dataset/for_training/Set5_x3.h5" \
--outputs_dir "/content/drive/My Drive/srcnn_pytorch/checkpoint" \
--scale 3 \
--lr 1e-4 \
--batch_size 16 \
--num_epochs 400 \
--num_workers 8 \
--seed 123

# %%
# !python3 "/content/drive/My Drive/srcnn_pytorch/test.py" \
--weights_file "/content/drive/My Drive/srcnn_pytorch/checkpoint/epoch_150.pth" \
--image_file "/content/drive/MyDrive/vdsr_pytorch/datasets/bird_GT_scale_3.bmp" \
--scale 3
